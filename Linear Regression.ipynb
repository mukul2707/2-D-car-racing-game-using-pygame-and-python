# %% [markdown]
# <a href="https://colab.research.google.com/github/mukul2707/2-D-car-racing-game-using-pygame-and-python/blob/master/Linear%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Regression**

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from pandas.plotting import scatter_matrix
import pandas.util.testing as tm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline

# %%
loan_data = pd.read_csv("http://spark-public.s3.amazonaws.com/dataanalysis/loansData.csv")
loan_data.head()
# Out:
#        Amount.Requested  ...  Employment.Length
# 81174             20000  ...           < 1 year
# 99592             19200  ...            2 years
# 80059             35000  ...            2 years
# 15825             10000  ...            5 years
# 33182             12000  ...            9 years
#
# [5 rows x 14 columns]

# %%
loan_data["Loan.Length"][0 : 10]
# Out:
# 81174    36 months
# 99592    36 months
# 80059    60 months
# 15825    36 months
# 33182    36 months
# 62403    36 months
# 48808    36 months
# 22090    60 months
# 76404    36 months
# 15867    36 months
# Name: Loan.Length, dtype: object

# %%
loan_data["Interest.Rate"][0:10]
# Out:
# 81174     8.90%
# 99592    12.12%
# 80059    21.98%
# 15825     9.99%
# 33182    11.71%
# 62403    15.31%
# 48808     7.90%
# 22090    17.14%
# 76404    14.33%
# 15867     6.91%
# Name: Interest.Rate, dtype: object

# %%
loan_data["FICO.Range"][0:10]
# Out:
# 81174    735-739
# 99592    715-719
# 80059    690-694
# 15825    695-699
# 33182    695-699
# 62403    670-674
# 48808    720-724
# 22090    705-709
# 76404    685-689
# 15867    715-719
# Name: FICO.Range, dtype: object

# %%
loan = pd.read_csv("loan.csv")
loan.head(100)
# Out:
#     Unnamed: 0  Interest.Rate   ...  Monthly.Income  Loan.Amount
# 0            6           15.31  ...         4891.67         6000
# 1           11           19.72  ...         3575.00         2000
# 2           12           14.27  ...         4250.00        10625
# 3           13           21.67  ...        14166.67        28000
# 4           21           21.98  ...         6666.67        22000
# ..         ...             ...  ...             ...          ...
# 95         526           15.96  ...         5583.33         6000
# 96         528           15.31  ...         6416.67         1800
# 97         531           11.14  ...         6833.33        15300
# 98         533           17.77  ...         4583.33        10500
# 99         534           17.77  ...        10268.25         6625
#
# [100 rows x 6 columns]

# %%
plt.figure()
loan = pd.read_csv("loan.csv")
fico = loan[' FICO.Score']
fico.hist(bins = 20)

# %%
plt.figure(figsize=(10,8))
loan = pd.read_csv("loan.csv")
x = loan.boxplot('Interest.Rate ',' FICO.Score')
x.set_xlabel("FICO Score")
x.set_ylabel("Interest Rate")
x.set_xticklabels(['650','  ','  ','  ','  ','675','  ','  ','  ','  ','700','  ','  ','  ','  ','725','  ','  ','  ','  ','750','  ','  ','  ','  ','775','  ','  ','  ','  ','800','  ','  ','  ','  ','825'])
#set_title
# Out:
# [Text(0, 0, '650'),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '675'),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '700'),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '725'),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '750'),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '775'),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '800'),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '  '),
#  Text(0, 0, '825')]

# %%
loan = pd.read_csv('loan.csv')
pd.plotting.scatter_matrix(loan,alpha=0.3,figsize=(10,10),diagonal='hist',color = 'red')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7fd642ecf8>,
# ...
#       dtype=object)

# %%
loan = pd.read_csv('loan.csv')
plt.scatter(loan[' FICO.Score'],loan['Interest.Rate '],color = 'red')
plt.xlabel('FICO Score')
plt.ylabel('Interest Rate')
# Out:
# Text(0, 0.5, 'Interest Rate')

# %%
plt.figure(figsize=(10,6))
loan = pd.read_csv('loan.csv')
plt.scatter(loan[' FICO.Score'],loan['Interest.Rate '],color = 'red')

plt.xlabel('FICO Score')
plt.ylabel('Interest Rate')
sns.lmplot(' FICO.Score', 'Interest.Rate ',data=loan)

# %%
X = loan[[ ' FICO.Score']]
X.shape
# Out:
# (2499, 1)

# %%
y = loan['Interest.Rate ']
y.shape
# Out:
# (2499,)

# %%
from sklearn.model_selection import train_test_split

X_train , X_test, y_train,y_test = train_test_split(X,y,test_size=0.4)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1499, 1)
# (1499,)
# (1000, 1)
# (1000,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train , y_train)
pred = model.predict(X_test)
pred[1]
# Out:
# 15.224555728130333

# %%
|loan.head()

# %%
loan1 = loan[loan['Unnamed: 0']==11]
loan1
loan1['Interest.Rate ']
# Out:
# 1    19.72
# Name: Interest.Rate , dtype: float64
